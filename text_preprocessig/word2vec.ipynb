# %%
from gensim.models import Word2Vec

# %%
import gensim.downloader as api

vec = api.load("word2vec-google-news-300")
# Out:
# [==============================--------------------] 60.7% 1010.0/1662.8MB downloaded
# ---------------------------------------------------------------------------
# ContentTooShortError                      Traceback (most recent call last)
# Cell In[3], line 3
#       1 import gensim.downloader as api
# ----> 3 vec = api.load("word2vec-google-news-300")
#
# File c:\Users\ravik\anaconda3\Lib\site-packages\gensim\downloader.py:496, in load(name, return_path)
#     494 path = os.path.join(folder_dir, file_name)
#     495 if not os.path.exists(folder_dir):
# --> 496     _download(name)
#     498 if return_path:
#     499     return path
#
# File c:\Users\ravik\anaconda3\Lib\site-packages\gensim\downloader.py:396, in _download(name)
#     394 fname = "{fname}.gz".format(fname=name)
#     395 dst_path = os.path.join(tmp_dir, fname)
# --> 396 urllib.urlretrieve(url_data, dst_path, reporthook=_progress)
#     397 if _calculate_md5_checksum(dst_path) == _get_checksum(name):
# ...

# %%
king = vec['king']

# %%
vec.most_similar('man')

# %%
vec.similar('man','boy')

# %%
ans = vec['king']-vec['man']-vec['women']
ans

# %%
vec.most_similar([[ans]])
