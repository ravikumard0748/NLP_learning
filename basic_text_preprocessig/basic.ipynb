# %%
import nltk
nltk.download('all')

# %% [markdown]
# ## tokenization

# %%
paragraph = """
"Natural Language Processing (NLP) is a fascinating field of Artificial Intelligence. It allows machines to understand, interpret, and generate human language. Common applications of NLP include chatbots, voice assistants like Siri or Alexa, machine translation, and sentiment analysis. As technology advances, NLP is becoming more accurate and accessible."
"""
sentences = nltk.sent_tokenize(paragraph)
word =  nltk.word_tokenize(paragraph)

# %%
print(sentences)
# Out:
# ['\n"Natural Language Processing (NLP) is a fascinating field of Artificial Intelligence.', 'It allows machines to understand, interpret, and generate human language.', 'Common applications of NLP include chatbots, voice assistants like Siri or Alexa, machine translation, and sentiment analysis.', 'As technology advances, NLP is becoming more accurate and accessible."']

# %%
print(word)
# Out:
# ["''", 'Natural', 'Language', 'Processing', '(', 'NLP', ')', 'is', 'a', 'fascinating', 'field', 'of', 'Artificial', 'Intelligence', '.', 'It', 'allows', 'machines', 'to', 'understand', ',', 'interpret', ',', 'and', 'generate', 'human', 'language', '.', 'Common', 'applications', 'of', 'NLP', 'include', 'chatbots', ',', 'voice', 'assistants', 'like', 'Siri', 'or', 'Alexa', ',', 'machine', 'translation', ',', 'and', 'sentiment', 'analysis', '.', 'As', 'technology', 'advances', ',', 'NLP', 'is', 'becoming', 'more', 'accurate', 'and', 'accessible', '.', "''"]

# %% [markdown]
# ## custom tokenization using Regex

# %%
import re

def custom_tokenizer(text):
    # Regex pattern to match words, numbers, emojis, punctuation
    pattern = r'\w+|[^\w\s]'  # words (\w+), or punctuation ([^\w\s])
    tokens = re.findall(pattern, text)
    return tokens

# Test text
text = "I love NLP! 😍 It's amazing, isn't it? Let's build custom-tokenizers."

tokens = custom_tokenizer(text)
print(tokens)
# Out:
# ['I', 'love', 'NLP', '!', '😍', 'It', "'", 's', 'amazing', ',', 'isn', "'", 't', 'it', '?', 'Let', "'", 's', 'build', 'custom', '-', 'tokenizers', '.']

# %%
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer

# %%
stem = PorterStemmer()
lemmatizer = WordNetLemmatizer()

# %% [markdown]
# ## Stop words and stemming

# %%
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

# %%
sentences = nltk.sent_tokenize(paragraph)
stemmer = PorterStemmer()

# %%
for i in range(len(sentences)):
    word = sentences[i]
    words = nltk.word_tokenize(word)
    sentence  = [stemmer.stem(word) for word in words if word not in stopwords.words('english')]
    sentences[i] = ' '.join(sentence)

# %%
sentences
# Out:
# ["'' natur languag process ( nlp ) fascin field artifici intellig .",
#  'it allow machin understand , interpret , gener human languag .',
#  'common applic nlp includ chatbot , voic assist like siri alexa , machin translat , sentiment analysi .',
#  "as technolog advanc , nlp becom accur access . ''"]

# %% [markdown]
# ## stemming and stopwords

# %%
from nltk.stem import WordNetLemmatizer
sentences = nltk.sent_tokenize(paragraph)
lem = WordNetLemmatizer()

hl= []

# %%
for i in range(len(sentences)):
    words = nltk.word_tokenize(sentences[i])
    words = [lem.lemmatize(word) for word in words if word not in stopwords.words('english')]
    hl.append(' '.join(words))

# %%
hl
# Out:
# ["'' Natural Language Processing ( NLP ) fascinating field Artificial Intelligence .",
#  'It allows machine understand , interpret , generate human language .',
#  'Common application NLP include chatbots , voice assistant like Siri Alexa , machine translation , sentiment analysis .',
#  "As technology advance , NLP becoming accurate accessible . ''"]

# %%
words
# Out:
# ['As',
#  'technology',
#  'advance',
#  ',',
#  'NLP',
#  'becoming',
#  'accurate',
#  'accessible',
#  '.',
#  "''"]

# %%
print(paragraph.lower())
# Out:
# "natural language processing (nlp) is a fascinating field of artificial intelligence. it allows machines to understand, interpret, and generate human language. common applications of nlp include chatbots, voice assistants like siri or alexa, machine translation, and sentiment analysis. as technology advances, nlp is becoming more accurate and accessible."
